# %%
import numpy as np

# %%
N = 300

# %%
A = np.ones((N,N))

# %%
# Upper triangle elements by row
# %timeit A[np.triu_indices(N)]
# Out:
# 883 µs ± 8.23 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Lower triangle elements by column
# %timeit A.T[np.triu_indices(N)]
# Out:
# 915 µs ± 30.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Upper triangle elements by column
# %timeit A.T[np.tril_indices(N)]
# Out:
# 877 µs ± 24.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Lower triangle elements by column
# %timeit A[np.tril_indices(N)]
# Out:
# 845 µs ± 13.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
