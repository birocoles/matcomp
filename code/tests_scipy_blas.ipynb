# %% [markdown]
# # Tests with `scipy.linalg.blas`

# %% [markdown]
# This code compares `numpy.dot` with low-level BLAS functions from `scipy.linalg.blas`<sup> 1 2 </sup>
#
# * <sup> 1 </sup>[Low-level BLAS functions (scipy.linalg.blas)](https://docs.scipy.org/doc/scipy/reference/linalg.blas.html)
#
# * <sup> 2 </sup>[BLAS (Basic Linear Algebra Subprograms)](http://www.netlib.org/blas/#_blas_routines)

# %%
import numpy as np
import numba as nb
from timeit import timeit

# %%
from scipy.linalg import blas

# %%
def matvec(A, x):
    N, M = A.shape
    y = np.zeros(N)
    for i in range(N):
        for j in range(M):
            y[i] += A[i,j]*x[j]
    return y

# %%
matvec_jit = nb.njit()(matvec)

# %%
N = 500
M = 460
A = np.ones((N,M))

# %%
x = np.random.rand(M)

# %%
# %timeit np.dot(A, x)
# Out:
# 32.7 µs ± 10.5 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit matvec(A, x)
# Out:
# 190 ms ± 5.99 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit matvec_jit(A, x)
# Out:
# 234 µs ± 10.5 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit blas.dgemv(1., A, x)
# Out:
# 387 µs ± 12 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
B = np.ones((N,M), order='F')

# %%
# %timeit blas.dgemv(1., B, x)
# Out:
# 27.9 µs ± 534 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
